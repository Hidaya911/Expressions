# %% [markdown]
# <a href="https://colab.research.google.com/github/Hidaya911/Expressions/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Dec 21 10:01:52 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="NqAQdXhV0myg6pSsuZnX")
project = rf.workspace("university-9qv06").project("facial-expression-5tqzd")
dataset = project.version(2).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.228, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Facial-Expression-2 in yolov8:: 100%|██████████| 292/292 [00:00<00:00, 1642.34it/s]

# %%
# !yolo task=detect  mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=1000 imgsz=640 patience=0
# Out:
# Streaming output truncated to the last 5000 lines.
#                    all         18         29      0.201      0.303      0.141     0.0761
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      5/1000      4.21G      1.143      2.163      1.408          2        640: 100% 8/8 [00:02<00:00,  3.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.37it/s]
#                    all         18         29      0.111      0.493      0.117     0.0658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      6/1000      4.36G      1.074      1.943      1.382          2        640: 100% 8/8 [00:01<00:00,  4.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.31it/s]
#                    all         18         29     0.0991      0.302      0.133     0.0798
#
# ...

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/confusion_matrix_normalized.png',width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train5/P_curve.png',width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train5/R_curve.png',width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train5/F1_curve.png',width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train5/val_batch0_pred.jpg',width=600)
# Out:
# /content

# %% [markdown]
# # Validate Custom Model

# %%
# !yolo task=detect  mode=val model={HOME}/runs/detect/train5/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/Facial-Expression-2/valid/labels.cache... 18 images, 0 backgrounds, 0 corrupt: 100% 18/18 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.04it/s]
#                    all         18         29      0.585      0.558      0.511      0.372
#                  angry         18          6      0.657      0.333      0.318      0.235
#                  happy         18          9       0.62          1      0.806      0.509
#                neutral         18          4      0.188        0.5      0.362      0.284
#                    sad         18         10      0.877        0.4      0.557      0.458
# Speed: 6.5ms preprocess, 33.4ms inference, 0.0ms loss, 45.4ms postprocess per image
# ...

# %% [markdown]
# # Test Set

# %%
# !yolo task=detect  mode=predict model={HOME}/runs/detect/train5/weights/best.pt conf=0.25 source={dataset.location}/test/images
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/9 /content/Facial-Expression-2/test/images/af166be9ffd676650ffdc5befd69ca61_jpg.rf.f70277f265565f5c38aada4c300be6ac.jpg: 640x640 (no detections), 16.4ms
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 2/9 /content/Facial-Expression-2/test/images/close-up-shot-young-man-staring_23-2148248468_jpg.rf.61589ddd42708bfed46f53104d372686.jpg: 640x640 1 neutral, 16.7ms
# image 3/9 /content/Facial-Expression-2/test/images/positive-bearded-man-hipster-smiles-broadly-has-pleased-expression-laughs-something-funny-closes-eyes_273609-16781_jpg.rf.0c7f3f4511819e0c760feb58378da7c2.jpg: 640x640 1 happy, 1 neutral, 16.4ms
# image 4/9 /content/Facial-Expression-2/test/images/side-view-beautiful-model-with-clear-skin_23-2149427919_jpg.rf.c5ca287a88211e0e20166c18914dbecc.jpg: 640x640 1 neutral, 16.3ms
# ...

# %%
import glob
from IPython.display import Image, display
image_paths = glob.glob(f'{HOME}/runs/detect/predict/*.jpg')
second_image_path = image_paths[1]  # Access the second image path

display(Image(filename=second_image_path, width=600))
print("\n")
